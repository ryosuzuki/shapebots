# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.txt',header=None)
df
# Out:
#        0    1    2
# 0     40   46  113
# 1     45   65  190
# 2     46   74  198
# 3     37   65  213
# 4     39   66  211
# 5     41   65  209
# 6     41   65  209
# 7     40   63  203
# 8     40   63  203
# 9     40   63  203
# 10    40   63  203
# 11    40   63  203
# 12    40   63  203
# 13    40   63  203
# 14    40   63  203
# 15    40   63  203
# 16    40   63  203
# 17    40   63  203
# 18    41   65  209
# 19    41   65  209
# 20    41   65  209
# 21    39   66  211
# 22    37   65  213
# 23    39   69  218
# 24    39   69  218
# 25    39   69  218
# 26    39   69  218
# 27    47   73  203
# 28    48   70  200
# 29    47   57  181
# ..   ...  ...  ...
# 279   43   62  201
# 280   43   62  201
# 281   43   62  201
# 282   43   62  201
# 283   41   65  209
# 284   39   66  211
# 285   37   65  213
# 286   39   69  218
# 287   39   69  218
# 288   39   69  218
# 289   46   75  204
# 290   45   60  186
# 291   43   50  153
# 292   35   43  103
# 293   35   43  103
# ...

# %%
plt.hist(df[0])
# Out:
# (array([ 24.,  62., 175.,  44.,   0.,   0.,   0.,   0.,   1.,   3.]),
#  array([  4.,  19.,  34.,  49.,  64.,  79.,  94., 109., 124., 139., 154.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df[1])
# Out:
# (array([ 43.,  34.,  52., 169.,   7.,   0.,   0.,   0.,   0.,   4.]),
#  array([ 19. ,  32.9,  46.8,  60.7,  74.6,  88.5, 102.4, 116.3, 130.2,
#         144.1, 158. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df[2])
# Out:
# (array([23., 20., 16., 18., 17., 22., 21., 26., 61., 85.]),
#  array([ 33. ,  52.2,  71.4,  90.6, 109.8, 129. , 148.2, 167.4, 186.6,
#         205.8, 225. ]),
#  <a list of 10 Patch objects>)
